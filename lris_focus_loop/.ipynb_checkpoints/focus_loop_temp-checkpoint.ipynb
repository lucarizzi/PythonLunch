# %%
from astropy.io import fits
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.visualization import astropy_mpl_style
from skimage.measure import profile_line
plt.style.use(astropy_mpl_style)
# %matplotlib inline

# %%
def return_mosaic(infile):
    # Set output image size 
    oxsize = 4096 
    oysize = 4623 

    # Set input image size 
    ixsize = 4096 
    iysize = 1155 

    # Create a numpy array with zeros 

    outimage = np.zeros((oxsize,oysize)) 

    # Open the fits file readonly by default and create an input hdulist 

    inlist = fits.open(infile) 
    inlist.info()
    nimages = len(inlist) - 1 
    print ("Number of images: %d\n" % (nimages))
    if (nimages < 1): 
      print ("This file does not appear to be a FITS MEF file." )
      return

    # Merge  the extension images into one numpy array 
    # The pattern here depends on how the images were placed in the MEF 
    print("add extentions")
    outimage[0:ixsize,0:iysize] = inlist[1].data 
    outimage[0:ixsize,iysize+1:iysize*2+1] = inlist[2].data 
    outimage[0:ixsize,iysize*2+2:iysize*3+2] = inlist[3].data 
    outimage[0:ixsize,iysize*3+3:iysize*4+3] = inlist[4].data 

    return outimage

# %%
images = ['bfoc0008.fits','bfoc0009.fits','bfoc0010.fits','bfoc0011.fits','bfoc0011.fits','bfoc0012.fits','bfoc0013.fits']

# %%
results = numpy.array([])
for image in images:
    image_data = return_mosaic(image)
    profile=profile_line(image_data,(100,300),(4000,300),10)
    profile = profile-numpy.median(profile)
    print(profile.max())
    results = numpy.append(results,profile.max())
# Out:
# Filename: bfoc0008.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     720   ()
#   1  VidInp1     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   2  VidInp2     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   3  VidInp3     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   4  VidInp4     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ac54679fb466> in <module>()
#       2 for image in images:
#       3     image_data = return_mosaic(image)
# ----> 4     profile=profile_line(image_data,(100,300),(4000,300),10)
#       5     profile = profile-numpy.median(profile)
#       6     print(profile.max())
#
# /Users/lrizzi/anaconda/lib/python3.6/site-packages/skimage/measure/profile.py in profile_line(img, src, dst, linewidth, order, mode, cval)
#      58     """
#      59     perp_lines = _line_profile_coordinates(src, dst, linewidth=linewidth)
# ---> 60     if img.ndim == 3:
#      61         pixels = [ndi.map_coordinates(img[..., i], perp_lines,
#      62                                       order=order, mode=mode, cval=cval)
#
# AttributeError: 'NoneType' object has no attribute 'ndim'

# %%
outimage = return_mosaic('bfoc0010.fits')
# Out:
# Filename: bfoc0010.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     720   ()
#   1  VidInp1     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   2  VidInp2     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   3  VidInp3     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
#   4  VidInp4     ImageHDU       360   (1155, 4096)   int16 (rescales to uint16)
# Number of images: 4
#
# add extentions

# %%
plt.imshow(outimage, cmap='gray',norm=LogNorm())

# %%
NBINS = 50
histogram = plt.hist(image_data.flatten(), NBINS)

# %%
import skimage

# %%
profile=skimage.measure.profile_line(image_data,(100,300),(4000,300),10)

# %%
plt.plot(profile)

# %%
numpy.median(profile)
# Out:
# 1404.7

# %%
profile = profile-numpy.median(profile)

# %%
profile
# Out:
# array([-22.7, -23.7, -23.5, ..., -19.3, -17.6, -19.4])

# %%
plt.plot(profile)
